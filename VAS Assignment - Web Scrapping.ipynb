# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pd

# %%
url="https://www.flipkart.com/search?q=whey+protein&sid=hlc%2Cetg%2C1rx&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_sc_na_na&as-pos=1&as-type=RECENT&suggestionId=whey+protein%7CProtein+Supplement&requestId=9a50884c-abc0-4015-9edc-93ea61af4acb&as-searchtext=wheyb"

# %%
allow = requests.get(url)

# %%
print(allow)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_name = soup.select(".s1Q9rs")

# %%
product_name
# Out:
# [<a class="s1Q9rs" href="/oziva-daily-protein-activ-men-clean-whey-protein-multivitamins-probiotics/p/itmb716652b2efa3?pid=PSLGBAGT6KEC8QEC&amp;lid=LSTPSLGBAGT6KEC8QECSVVDMJ&amp;marketplace=FLIPKART&amp;q=whey+protein&amp;store=hlc%2Fetg%2F1rx&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_5_sc_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_sc_na_na&amp;fm=organic&amp;iid=en_TBOu7jf6p4atsKQX%2Fa%2FrQEI4xYRHt3nEqVlAL%2Bk5n3D03JAYxkOfWAo1uhEIF0dIlf5j86EujqDV1cysFh0TwQ%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=wdbbpodtds0000001653892828110&amp;qH=fb66386045d59cb3" rel="noopener noreferrer" target="_blank" title="OZiva Daily Protein Activ For Men with Clean Whey Protein, Multivitamins &amp; Probiotics Whey Protein">OZiva Daily Protein Activ For Men with Clean Whey Prote...</a>,
# ...

# %%
product_list =[]

# %%
product_link =[]

# %%
for item in product_name:
    product_list.append(item.text)
    link= "https://www.flipkart.com/"
    product_link.append(link)

# %%
product_list
# Out:
# ['OZiva Daily Protein Activ For Men with Clean Whey Prote...',
#  'GNC Pro Performance 100% Whey Protein',
#  "MUSCLEBLAZE Beginner's Whey Protein",
#  'BIGMUSCLES NUTRITION Premium Gold Whey Whey Protein',
#  'BIGMUSCLES NUTRITION Essential Whey Protein | 24g Prote...',
#  'Nutrabay Pure 100% Whey Protein Concentrate || Raw Whey...',
#  'AS-IT-IS Nutrition Whey Protein Concentrate 80% Unflavo...',
#  'OZiva Protein & Herbs,Women with Ayurvedic Herbs, for B...',
#  'XLR8 Classic Whey , 24 g Protein, 5.5 BCAA, No Maltodex...',
#  'Optimum Nutrition (ON) Gold Standard 100% Protein Powde...',
#  'Nakpro PERFORM Whey Protein Supplement Powder Whey Prot...',
#  "Healthy Origins Beginner's Gold Raw Isolate Whey Protei...",
#  "MUSCLEBLAZE Beginner's Protein (Jar Pack), Whey Supplem...",
#  'MUSCLEBLAZE Fuel One Whey Protein, 24 g Protein, 5.29 B...',
#  'Optimum Nutrition (ON) Gold Standard 100% Protein Powde...',
#  'HEALTHOXIDE My First Protein with whey, casein & pea, C...',
# ...

# %%
rate_list = soup.select("._8VNy32 ._30jeq3")

# %%
rate_list
# Out:
# [<div class="_30jeq3">₹434</div>,
#  <div class="_30jeq3">₹4,439</div>,
#  <div class="_30jeq3">₹437</div>,
#  <div class="_30jeq3">₹1,639</div>,
#  <div class="_30jeq3">₹913</div>,
#  <div class="_30jeq3">₹839</div>,
#  <div class="_30jeq3">₹1,639</div>,
#  <div class="_30jeq3">₹1,367</div>,
#  <div class="_30jeq3">₹1,039</div>,
#  <div class="_30jeq3">₹1,597</div>,
#  <div class="_30jeq3">₹1,273</div>,
#  <div class="_30jeq3">₹344</div>,
#  <div class="_30jeq3">₹1,339</div>,
#  <div class="_30jeq3">₹1,099</div>,
#  <div class="_30jeq3">₹3,239</div>,
#  <div class="_30jeq3">₹659</div>,
#  <div class="_30jeq3">₹1,649</div>,
#  <div class="_30jeq3">₹2,952</div>,
#  <div class="_30jeq3">₹3,091</div>,
#  <div class="_30jeq3">₹3,889</div>,
#  <div class="_30jeq3">₹2,439</div>,
#  <div class="_30jeq3">₹1,212</div>,
#  <div class="_30jeq3">₹895</div>,
#  <div class="_30jeq3">₹1,789</div>,
#  <div class="_30jeq3">₹1,710</div>,
#  <div class="_30jeq3">₹1,649</div>,
# ...

# %%
rate=[]

# %%
for item in rate_list:
    rate.append(item.text)

# %%
rate
# Out:
# ['₹434',
#  '₹4,439',
#  '₹437',
#  '₹1,639',
#  '₹913',
#  '₹839',
#  '₹1,639',
#  '₹1,367',
#  '₹1,039',
#  '₹1,597',
#  '₹1,273',
#  '₹344',
#  '₹1,339',
#  '₹1,099',
#  '₹3,239',
#  '₹659',
#  '₹1,649',
#  '₹2,952',
#  '₹3,091',
#  '₹3,889',
#  '₹2,439',
#  '₹1,212',
#  '₹895',
#  '₹1,789',
#  '₹1,710',
#  '₹1,649',
#  '₹1,139',
#  '₹1,388',
#  '₹3,259',
#  '₹6,739',
#  '₹1,439',
#  '₹4,440',
#  '₹1,824',
#  '₹1,789',
#  '₹1,689',
#  '₹2,339',
#  '₹1,389',
#  '₹1,477',
#  '₹1,239',
#  '₹1,605']

# %%
import pandas as pd

# %%
product = pd.DataFrame(product_name,columns=["Product_name"])

# %%
product["Price"]=rate

# %%
product
# Out:
#                                          Product_name   Price
# 0   OZiva Daily Protein Activ For Men with Clean W...    ₹434
# 1               GNC Pro Performance 100% Whey Protein  ₹4,439
# 2                 MUSCLEBLAZE Beginner's Whey Protein    ₹437
# 3   BIGMUSCLES NUTRITION Premium Gold Whey Whey Pr...  ₹1,639
# 4   BIGMUSCLES NUTRITION Essential Whey Protein | ...    ₹913
# 5   Nutrabay Pure 100% Whey Protein Concentrate ||...    ₹839
# 6   AS-IT-IS Nutrition Whey Protein Concentrate 80...  ₹1,639
# 7   OZiva Protein & Herbs,Women with Ayurvedic Her...  ₹1,367
# 8   XLR8 Classic Whey , 24 g Protein, 5.5 BCAA, No...  ₹1,039
# 9   Optimum Nutrition (ON) Gold Standard 100% Prot...  ₹1,597
# 10  Nakpro PERFORM Whey Protein Supplement Powder ...  ₹1,273
# 11  Healthy Origins Beginner's Gold Raw Isolate Wh...    ₹344
# 12  MUSCLEBLAZE Beginner's Protein (Jar Pack), Whe...  ₹1,339
# 13  MUSCLEBLAZE Fuel One Whey Protein, 24 g Protei...  ₹1,099
# ...

# %%
product.to_csv("Assignment.csv")
